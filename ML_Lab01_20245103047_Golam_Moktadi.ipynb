# %%
# LAB 1: Welcome to Machine Learning
# Student name:Golam Moktadi
# Student ID:20245103047
print("Hello, future ML detective!")
print("Rule 1: The computer is literal, not rude.")
# Out:
# Hello, future ML detective!
# Rule 1: The computer is literal, not rude.

# %%
import numpy as np

np.random.seed(42)

marks = np.array([55, 72, 48, 90, 66, 81])

print("Marks:", marks)
print("Mean:", marks.mean())
print("Highest:", marks.max())
print("Passed:", marks[marks >= 50])

print("Minimum:", marks.min())
print("Standard Deviation:", marks.std())

bonus_marks = marks + 5

print("Original Marks:", marks)
print("Marks after 5 bonus:", bonus_marks)

passed_count = np.sum(marks >= 50)

print("Number of students passed:", passed_count)

matrix = marks.reshape(2, 3)

print("2 x 3 Matrix:")
print(matrix)
# Out:
# Marks: [55 72 48 90 66 81]
# Mean: 68.66666666666667
# Highest: 90
# Passed: [55 72 90 66 81]
# Minimum: 48
# Standard Deviation: 14.372040758206733
# Original Marks: [55 72 48 90 66 81]
# Marks after 5 bonus: [60 77 53 95 71 86]
# Number of students passed: 5
# 2 x 3 Matrix:
# [[55 72 48]
#  [90 66 81]]

# %%
import pandas as pd

data = {
    'student': ['Asha', 'Babu', 'Chayan', 'Dipa', 'Emon', 'Farah'],
    'study_hours': [2, 5, 1, 7, 3, 6],
    'sleep_hours': [8, 6, 9, 5, 7, 6],
    'attendance': [70, 88, 55, 95, 75, 91],
    'snacks': [3, 2, 5, 1, 4, 2],
    'passed': ['Yes', 'Yes', 'No', 'Yes', 'No', 'Yes']
}

df = pd.DataFrame(data)

print("Original DataFrame:")
display(df)

print("\nDataFrame Information:")
df.info()

print("\nDescriptive Statistics:")
print(df.describe())

features = ['study_hours', 'sleep_hours', 'attendance', 'snacks']
label = 'passed'

print("\n16. Features:", features)
print("16. Label:", label)

print("\n17. Number of samples:", df.shape[0])
print("Number of columns:", df.shape[1])

print("\n18. Students with attendance at least 80:")
display(df[df['attendance'] >= 80])

passed_students = df[df['passed'] == 'Yes']
average_study_hours = passed_students['study_hours'].mean()

print("\n19. Average study hours for students who passed:",
      average_study_hours)

print("\n20. DataFrame sorted by attendance:")
display(df.sort_values(by='attendance', ascending=False))

print("\n21. Answer:")
print("No. This tiny dataset does not prove that snack purchases cause failure.")
print("A pattern or correlation is only a clue, not proof of causation.")
print("Other factors may also affect whether a student passes or fails.")
# Out:
# Original DataFrame:
#   student  study_hours  sleep_hours  attendance  snacks passed
# 0    Asha            2            8          70       3    Yes
# 1    Babu            5            6          88       2    Yes
# 2  Chayan            1            9          55       5     No
# 3    Dipa            7            5          95       1    Yes
# 4    Emon            3            7          75       4     No
# 5   Farah            6            6          91       2    Yes
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student      6 non-null      object
#  1   study_hours  6 non-null      int64
#  2   sleep_hours  6 non-null      int64
#  3   attendance   6 non-null      int64
#  4   snacks       6 non-null      int64
#  5   passed       6 non-null      object
# dtypes: int64(4), object(2)
# ...

# %%
# Activity D — Reproducibility Experiment

import random
import numpy as np

def generate_scores(use_seed):
    if use_seed:
        random.seed(42)
        np.random.seed(42)

    return np.random.randint(40, 101, size=5)


print("Seeded run 1:", generate_scores(True))
print("Seeded run 2:", generate_scores(True))
print("Unseeded run 1:", generate_scores(False))
print("Unseeded run 2:", generate_scores(False))
# Out:
# Seeded run 1: [78 91 68 54 82]
# Seeded run 2: [78 91 68 54 82]
# Unseeded run 1: [ 47 100  60  78  97]
# Unseeded run 2: [58 62 50 50 63]

# %%
# Activity E — Map the Modern ML Workflow

problem_statement = "Predict whether a student will pass based on study habits, sleep, attendance, and snack purchases."

print("1. Problem")
print("Problem Statement:", problem_statement)

dataset_source = "Small sample student dataset provided in the lab."
dataset_description = "The dataset contains student study hours, sleep hours, attendance, snacks, and pass/fail status."

print("\n2. Data")
print("Dataset Source:", dataset_source)
print("Dataset Description:", dataset_description)


preparation = [
    "Check for missing values",
    "Check for duplicate rows",
    "Check for unusual or biased data",
    "Avoid data leakage"
]

print("\n3. Preparation")
for item in preparation:
    print("-", item)

baseline = "Use a simple baseline such as predicting the most common class."

print("\n4. Baseline")
print("Baseline Configuration:", baseline)


metrics = ["Accuracy", "Precision", "Recall", "F1-score"]

print("\n5. Evaluation")
print("Metrics:", metrics)
print("Use a fixed train-test split for fair comparison.")

improvement = "Test a different ML method and compare its performance with the baseline."

print("\n6. Improvement")
print("Proposed Method:", improvement)
print("Ablation: Remove one feature at a time and observe the performance change.")

communication = [
    "Document the dataset",
    "Explain the preprocessing steps",
    "Record the model configuration",
    "Report the evaluation results",
    "Mention limitations",
    "Provide code so others can reproduce the experiment"
]

print("\n7. Communication")
for item in communication:
    print("-", item)

print("\nFinal Lesson:")
print("High accuracy alone is not enough.")
print("We also need the data, preparation steps, evaluation method,")
print("model details, evidence, and limitations.")
# Out:
# 1. Problem
# Problem Statement: Predict whether a student will pass based on study habits, sleep, attendance, and snack purchases.
#
# 2. Data
# Dataset Source: Small sample student dataset provided in the lab.
# Dataset Description: The dataset contains student study hours, sleep hours, attendance, snacks, and pass/fail status.
#
# 3. Preparation
# - Check for missing values
# - Check for duplicate rows
# - Check for unusual or biased data
# - Avoid data leakage
#
# 4. Baseline
# Baseline Configuration: Use a simple baseline such as predicting the most common class.
#
# 5. Evaluation
# Metrics: ['Accuracy', 'Precision', 'Recall', 'F1-score']
# Use a fixed train-test split for fair comparison.
#
# 6. Improvement
# Proposed Method: Test a different ML method and compare its performance with the baseline.
# Ablation: Remove one feature at a time and observe the performance change.
#
# 7. Communication
# - Document the dataset
# - Explain the preprocessing steps
# ...
